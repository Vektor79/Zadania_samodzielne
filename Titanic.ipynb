# %% [markdown]
# <a href="https://colab.research.google.com/github/Vektor79/Zadania_samodzielne/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kiedy Titanic zatonął, zginęło 1502 z 2224 przebywających na nim osób. Ta sensacyjna tragedia wstrząsnęła społecznością międzynarodową i doprowadziła do udoskonalenia przepisów bezpieczeństwa dla statków. Katastrofa pochłonęła tak wiele ludzkich żyć, m.in. dlatego, że na statku nie znalazło się wystarczająco dużo łodzi ratunkowych.
#
# O przeżyciu na pewno w pewnym stopniu decydowało szczęście, co nie zmienia faktu, że niektórzy mieli obiektywnie większe szanse na przeżycie niż inni. Pierwszeństwo do skorzystania z szalup ratunków zależało m.in. od płci czy klasy, w której dana osoba podróżowała. W tym zadaniu użyjesz zbioru danych zawierających informacje o 891 prawdziwych pasażerach Titanica. Każdy wiersz reprezentuje jedną osobę.
#
# Wyjaśnijmy znaczenie poszczególnych zmiennych (kolumn) w zbiorze titanic:
#
# # zmienna	| definicja	| klucz-wartość
#
# survival -->   |status przeżycia   |	0 = nie przeżył, 1 = przeżył
#
# ---
# pclass	-->    | klasa na bilecie	| 1 = pierwsza klasa, 2 = druga klasa, 3 =
#                                   trzecia klasa
#
# ---
# sex	  -->      | płeć
#
# ---
# age   -->    	| wiek w latach
#
# ---
# sibsp -->    	| liczba rodzeństwa/małżonków na pokładzie
#
# ---
# parch	-->      | liczba rodziców/dzieci na pokładzie
#
# ---
# ticket	-->    | numer biletu
#
# ---
# fare	 -->     | taryfa pasażerska
#
# ---
# cabin	 -->     | numer kabiny
#
# ---
# embarked	 --> | port zaokrętowania| C = Cherbourg, Q = Queenstown, S =
#                                  Southampton
#
# ---
# class  -->   	| klasa na bilecie	| First, Second, Third
#
# ---
# who	 -->       | płeć	            | man, woman
#
# ---
# adult_male	--> | dorosły	          | True, False
#
# ---
# deck	 -->     | pokład
#
# ---
# embark_town	--> | port zaokrętowania| Cherbourg, Queenstown, Southampton
#
# ---
# alive	-->      | status przeżycia	| yes, no
#
# ---
# alone	 -->     | sam na statku	    | True, False
#
# ---
#
#
# # Treść zadania:
#
#
#
# 1.   Utwórz nowy notatnik w Google Colab o nazwie titanic.ipynb i zaimportuj bibliotekę seaborn.  ✅
# 2.   Do zmiennej titanic_data przypisz zbiór danych titanic załadowany za pomocą odpowiedniej funkcji z biblioteki seaborn (zbiór danych nazywa się titanic).   ✅
# 3. Wyświetl zbiór danych lub 10 ostatnich wpisów tego zbioru. Wskazówka: użyj funkcji .tail().  ✅
# 4. Ustaw styl wykresu na darkgrid.  ✅
# 5. Wygeneruj histogram, który zobrazuje, ilu pasażerów było przypisanych do każdej z klas biletu.   ✅
# 6. Wygeneruj wykres punktowy, który pokaże zależność między wiekiem pasażera a taryfą pasażerską w podziale na płeć. Przypisz wykres do zmiennej plot.  ✅
# 7. Zapisz drugi wykres w głównym katalogu Google Colab. Ustaw nazwę pliku na titanic.png. Pobierz plik z wykresem na dysk swojego komputera.  ✅

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic_data = sns.load_dataset('titanic')
titanic_data.tail(10)

sns.set_style('darkgrid')
titanic_data['class'].hist()

plot = sns.relplot(x='age', y='fare', hue='sex', data=titanic_data)
plt.show()

plot.figure.savefig('titanic.png')
